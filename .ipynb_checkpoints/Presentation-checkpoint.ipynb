# %% [markdown]
# # OpenIFS SCM
#
# Organisation: ECMWF
#
# License: The following notebook is a run of an example in a ECMWF training course.
#
# Article: #### ADD the link when is going to be published ###
#
# Goal: Facilitate usage of the single column model of ECMWF's IFS. Showcase how a modern, interactive, development environment can enhance scientific productivity for ECMWF’s Integrated Forecasting System (IFS).

# %%
# Import the run script from the scripts directory. And build the Open ifs source.
import scripts.run as run
from importlib import reload
run = reload(run)
run.build_run()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-65b86beb4a72> in <module>
#       1 # Import the run script from the scripts directory. And build the Open ifs source.
# ----> 2 import scripts.run as run
#       3 from importlib import reload
#       4 run = reload(run)
#       5 run.build_run()
#
# ModuleNotFoundError: No module named 'scripts'

# %%
# Restart the kernel so the saved fortran variables will not bouther us anymore.
import os
from IPython.display import display_html
display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
# Run OpenIfs
import os
from importlib import reload

if os.path.isdir("test-run"):
    # %cd test-run

os.environ["GFORTRAN_CONVERT_UNIT"] = "big_endian"
import _test1
_test1.f90wrap_cnt1c()
# Out:
# /home/tibi/Desktop/esowc/test-run

# %%
# A little bit more about the save variables
# FORTRAN has a very interesting way of handeling variables with the SAVE directive;
# It keeps the variable in memory for as long as the module is runned
# and if we realocate it fails the kernel; this si why we restart the kernels
# I am now working on another solution to this. Unloading the dll by hand but the
# api of the cython is rather unpleasant
# also added all of the imports here to have a cleaner interface
# Simplest solution for a hard problem just restart the kernel after a run to make Fortran not care about
# plot the results
import _test1
import sys

import os

if os.path.isdir("test-run"):
    # %cd test-run
    
import importlib
sys.path.append("..")
from scripts import plot

from scripts import get_nl_class

import scripts.plot

plot = plot.Plot("diagvar.nc")

# %%
# Select the variables that you want to plot 
plot.documentation_nl_names()
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# int32 nlev(nlev)
#     units: count
#     long_name: Atmospheric Model Levels
# unlimited dimensions:
# current shape = (91,)
# filling on, default _FillValue of -2147483647 used
#
# <class 'netCDF4._netCDF4.Variable'>
# int32 nlevp1(nlevp1)
#     units: count
#     long_name: Atmospheric Model Levels
# unlimited dimensions:
# current shape = (92,)
# filling on, default _FillValue of -2147483647 used
#
# <class 'netCDF4._netCDF4.Variable'>
# int32 nlevs(nlevs)
#     units: count
#     long_name: Soil/Sea-Ice Model Levels
# unlimited dimensions:
# current shape = (4,)
# filling on, default _FillValue of -2147483647 used
#
# <class 'netCDF4._netCDF4.Variable'>
# int32 ntiles(ntiles)
#     units: count
#     long_name: Tiles
# unlimited dimensions:
# current shape = (9,)
# filling on, default _FillValue of -2147483647 used
#
# <class 'netCDF4._netCDF4.Variable'>
# int32 norg(norg)
#     units: count
#     long_name: Orographic Variances
# unlimited dimensions:
# current shape = (4,)
# filling on, default _FillValue of -2147483647 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 time(time)
#     units: seconds
#     long_name: Time
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# int32 ncextr(ncextr)
#     units: count
#     long_name: Extra Variable Levels
# unlimited dimensions:
# current shape = (91,)
# filling on, default _FillValue of -2147483647 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 pressure_f(time, nlev)
#     units: Pa
#     long_name: Pressure - full levels
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 pressure_h(time, nlevp1)
#     units: Pa
#     long_name: Pressure - half levels
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 height_f(time, nlev)
#     units: m
#     long_name: Height - full levels
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 height_h(time, nlevp1)
#     units: m
#     long_name: Height - half levels
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 wat_vap_path(time)
#     units: kg/m^2
#     long_name: Water Vapor Path
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 liq_wat_path(time)
#     units: kg/m^2
#     long_name: Liquid Water Path
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 ice_wat_path(time)
#     units: kg/m^2
#     long_name: Ice Water Path
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 pbl_height(time)
#     units: m
#     long_name: Boundary Layer Height
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 total_cloud(time)
#     units: 1
#     long_name: Total Cloud Cover
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 low_cloud(time)
#     units: 1
#     long_name: Low Cloud Cover
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 middle_cloud(time)
#     units: 1
#     long_name: Middle Cloud Cover
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 high_cloud(time)
#     units: 1
#     long_name: High Cloud Cover
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 conv_rain(time)
#     units: kg/m^2/s
#     long_name: Convective Rain
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 conv_snow(time)
#     units: kg/m^2/s
#     long_name: Convective Snow
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 stra_rain(time)
#     units: kg/m^2/s
#     long_name: Stratiform Rain
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 stra_snow(time)
#     units: kg/m^2/s
#     long_name: Stratiform Snow
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 top_swrad_inc(time)
#     units: W/m^2
#     long_name: Top SW Radiation Incoming
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 conv_type(time)
#     units: 0/1/2/3
#     long_name: Deep/Shallow/Midlevel Convection
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 pbl_type(time)
#     units: 0/1/2/3
#     long_name: Dry stable/Dry conv/Sc/Cu
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 n_conv_base(time)
#     units: 1
#     long_name: Index of Convective Cloud Base
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 n_conv_top(time)
#     units: 1
#     long_name: Index of Convective Cloud Top
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 top_swrad(time)
#     units: W/m^2
#     long_name: Top SW Radiation
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 top_swrad_clr(time)
#     units: W/m^2
#     long_name: Top SW Radiation Clear-Sky
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 top_lwrad(time)
#     units: W/m^2
#     long_name: Top LW Radiation
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 top_lwrad_clr(time)
#     units: W/m^2
#     long_name: Top LW Radiation Clear-Sky
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sfc_swrad(time)
#     units: W/m^2
#     long_name: Surface SW Radiation
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sfc_swrad_clr(time)
#     units: W/m^2
#     long_name: Surface SW Radiation Clear-Sky
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sfc_lwrad(time)
#     units: W/m^2
#     long_name: Surface LW Radiation
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sfc_lwrad_clr(time)
#     units: W/m^2
#     long_name: Surface LW Radiation Clear-Sky
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sfc_swrad_down(time)
#     units: W/m^2
#     long_name: Surface Downward SW Radiation
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sfc_albedo(time)
#     units: 1
#     long_name: Surface SW Albedo
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sfc_lwrad_down(time)
#     units: W/m^2
#     long_name: Surface Downward LW Radiation
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sfc_emiss(time)
#     units: 1
#     long_name: Surface Emissivity
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sfc_sen_flx(time)
#     units: W/m^2
#     long_name: Surface Sensible Heat Flux
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sfc_lat_flx(time)
#     units: W/m^2
#     long_name: Surface Latent Heat Flux
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 u_sfc_strss(time)
#     units:
#     long_name: U-Surface Stress
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 v_sfc_strss(time)
#     units:
#     long_name: V-Surface Stress
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sfc_sen_flx_ti(time, nlev)
#     units: W/m^2
#     long_name: Tiled Surface Sensible Heat Flux
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sfc_lat_flx_ti(time, nlev)
#     units: W/m^2
#     long_name: Tiled Surface Latent Heat Flux
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 u_sfc_strss_ti(time, nlev)
#     units: N/m^2
#     long_name: Tiled U Surface Stress
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 v_sfc_strss_ti(time, nlev)
#     units: N/m^2
#     long_name: Tiled V Surface Stress
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sst(time)
#     units: K
#     long_name: Sea Surface Temperature
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 t_skin_ti(time, nlev)
#     units: K
#     long_name: Tiled Skin Temperature
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 land_sea_mask(time)
#     units: 0-1
#     long_name: Land-Sea Mask
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sea_ice_cov(time)
#     units: 0-1
#     long_name: Sea Ice Fraction
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 rough_len_mom(time)
#     units: m
#     long_name: Surface Roughness length
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 rough_len_heat(time)
#     units: m
#     long_name: Surface Roughness Length for Heat
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 low_veg_cov(time)
#     units: 0-1
#     long_name: Low Vegetation Cover
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 high_veg_cov(time)
#     units: 0-1
#     long_name: High Vegetation Cover
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 low_veg_type(time)
#     units: 1-20
#     long_name: Low Vegetation Type
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 high_veg_type(time)
#     units: 1-20
#     long_name: High Vegetation Type
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 turb_diss(time)
#     units:
#     long_name: Turbulent Dissipation
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 gwd_diss(time)
#     units:
#     long_name: Gravity Wave Drag Dissipation
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 gwd_u_strs(time)
#     units:
#     long_name: Gravity Wave Drag Surface U-Stress
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 gwd_v_strs(time)
#     units:
#     long_name: Gravity Wave Drag Surface V-Stress
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 u_wind_10m(time)
#     units: m/s
#     long_name: U-Wind 10m
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 v_wind_10m(time)
#     units: m/s
#     long_name: V-Wind 10m
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 temperature_2m(time)
#     units: K
#     long_name: Temperature 2m
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 dew_point_2m(time)
#     units: K
#     long_name: Dew Point Temperature 2m
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 wind_gust(time)
#     units: m/s
#     long_name: Wind Gust at 10m
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sun_duration(time)
#     units: 0-1
#     long_name: Sunshine Duration
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 runoff(time)
#     units:
#     long_name: Run-off
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sfc_sen_flx_ext(time)
#     units: W/m^2
#     long_name: External Sensible Heat Flux
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sfc_lat_flx_ext(time)
#     units: W/m^2
#     long_name: External Latent Heat Flux
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 dir_orog_var(time, norg)
#     units:
#     long_name: Directional Orographic Variances
# unlimited dimensions: time
# current shape = (289, 4)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 ls_prec_fct(time, nlev)
#     units: 0-1
#     long_name: Large-scale Precipitation Fraction
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_u_wind(time, nlev)
#     units: m/s^2
#     long_name: Tendency of U-Wind
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_u_wind_d(time, nlev)
#     units: m/s^2
#     long_name: Tendency of U-Wind (dyn)
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_u_wind_p(time, nlev)
#     units: m/s^2
#     long_name: Tendency of U-Wind (phy)
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_v_wind(time, nlev)
#     units: m/s^2
#     long_name: Tendency of V-Wind
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_v_wind_d(time, nlev)
#     units: m/s^2
#     long_name: Tendency of V-Wind (dyn)
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_v_wind_p(time, nlev)
#     units: m/s^2
#     long_name: Tendency of V-Wind (phy)
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_temp(time, nlev)
#     units: K/s
#     long_name: Tendency of Temperature
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_temp_d(time, nlev)
#     units: K/s
#     long_name: Tendency of Temperature (dyn)
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_temp_p(time, nlev)
#     units: K/s
#     long_name: Tendency of Temperature (phy)
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_wat_vap(time, nlev)
#     units: 1/s
#     long_name: Tendency of Water Vapor
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_wat_vap_d(time, nlev)
#     units: 1/s
#     long_name: Tendency of Water Vapor (dyn)
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_wat_vap_p(time, nlev)
#     units: 1/s
#     long_name: Tendency of Water Vapor (phy)
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_cld_fract(time, nlev)
#     units: 1/s
#     long_name: Tendency of Cloud Fraction
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_cld_fract_d(time, nlev)
#     units: 1/s
#     long_name: Tendency of Cloud Fraction (dyn)
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_cld_fract_p(time, nlev)
#     units: 1/s
#     long_name: Tendency of Cloud Fraction (phy)
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_cld_liq(time, nlev)
#     units: 1/s
#     long_name: Tendency of Cloud Liq. Water
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_cld_liq_d(time, nlev)
#     units: 1/s
#     long_name: Tendency of Cloud Liq. Water (dyn)
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_cld_liq_p(time, nlev)
#     units: 1/s
#     long_name: Tendency of Cloud Liq. Water (phy)
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_cld_ice(time, nlev)
#     units: 1/s
#     long_name: Tendency of Cloud Ice Water
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_cld_ice_d(time, nlev)
#     units: 1/s
#     long_name: Tendency of Cloud Ice Water (dyn)
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_cld_ice_p(time, nlev)
#     units: 1/s
#     long_name: Tendency of Cloud Ice Water (phy)
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 stra_rain_3d(time, nlevp1)
#     units:
#     long_name: Stratiform Rain 3D
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 stra_snow_3d(time, nlevp1)
#     units:
#     long_name: Stratiform Snow 3D
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 conv_rain_3d(time, nlevp1)
#     units:
#     long_name: Convective Rain 3D
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 conv_snow_3d(time, nlevp1)
#     units:
#     long_name: Convective Snow 3D
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 conv_flx_wv(time, nlevp1)
#     units:
#     long_name: Conv. Flux of WV
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 conv_flx_s(time, nlevp1)
#     units: W/m^2
#     long_name: Conv. Flux of Dry Static Energy
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 conv_flx_u(time, nlevp1)
#     units:
#     long_name: Convective U-Momentum Flux
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 conv_flx_v(time, nlevp1)
#     units:
#     long_name: Convective V-Momentum Flux
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 cond_detrained_updr(time, nlev)
#     units:
#     long_name: Detrained liquid water
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 cond_updraft(time, nlev)
#     units:
#     long_name: Liquid water content in updrafts
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 turb_flx_wv(time, nlevp1)
#     units:
#     long_name: Turb. Flux (inc. neg q) of WV
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 turb_flx_s(time, nlevp1)
#     units: W/m^2
#     long_name: Turb. Flux of Dry Static Energy
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 turb_flx_u(time, nlevp1)
#     units:
#     long_name: Turbulent Flux of U-Momentum
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 turb_flx_v(time, nlevp1)
#     units:
#     long_name: Turbulent Flux of V-Momentum
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 turb_flx_ice(time, nlevp1)
#     units:
#     long_name: Turbulent Flux (inc. neg. q) of Ice Water
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 turb_flx_liq(time, nlevp1)
#     units:
#     long_name: Turbulent Flux (inc. neg. q) of Liq. Water
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 gwd_flx_u(time, nlevp1)
#     units:
#     long_name: Gravity Wave Drag U-Flux
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 gwd_flx_v(time, nlevp1)
#     units:
#     long_name: Gravity Wave Drag V-Flux
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sw_rad_flux(time, nlevp1)
#     units:
#     long_name: SW radiative Flux
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 lw_rad_flux(time, nlevp1)
#     units:
#     long_name: LW radiative Flux
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used

# %%
# Call the plot function and plot the result.

plot.plot_parameter(plot_name = "pressure_f")

# %%
# Change the fortran Namelist
# Firstly look for what variable you want to change

get_nl_class = importlib.reload(get_nl_class)
namelist_changer = get_nl_class.NML_Change(namelist_file = "fort.4")
namelist_changer.read_nml()
namelist_changer.print_namelists_from_file()
# Out:
#  &NAMCT0
#
#     NFRPOS=1,
#
#     LSLPHY=T, ! F for euler
#
#     LTWOTL=T,
#
#     LREGETA=T, ! F for euler
#
#     NUNDEFLD=1, ! for bound checking
#
# /
#
#  &NAMARG
#
#   UTSTEP=300.0 ! 300.0, for euler
#
#   LSLAG=T, ! F for euler
#
# /
#
#  &NAMRIP
#
#   NSTOP=288, ! 864, for euler
#
# /
#
#  &NAMCVER
#
#   LVERTFE=.false.,
#
# /
#
#  &NAMDYN
#
#     NITMP=3, ! makes advection further more accurate
#
#     ! LSETTLS=.false., ! alternative SL scheme
#
# /
#
#  &NAERAD
#
#     NRADFR=1,
#
#     LSRTM=T,
#
#     NLIQOPT=2,
#
#     NRADINT=0,
#
#     NRPROMA=-1,
#
# /
#
#  &NAMDIM
#
#     NFLEVG=91,
#
# 	NIOLEVG=91,
#
#     NSMAX=159,
#
#     NSTENCILWIDE=1,
#
#     NPROMA=-1,
#
#     NDGLG=1,
#
#     NDLON=1,
#
# /
#
#  &NAEPHY
#
#     LEPHYS=T,
#
#     LEFLAKE=T,
#
#     LESURF=T,
#
#     LEVDIF=T,
#
#     LECUMF=T,
#
#     LEPCLD=T,
#
#     LEQNGT=T,
#
#     LEGWDG=T,
#
#     LERADI=T,
#
#     LEGWWMS=T,
#
#     LBUD23=F,
#
# /
#
#  &NAM1C
#
#     NSTRTINI=1,
#
#     LDYNFOR=T,
#
#     LUGVG=F,
#
#     LVERVEL=T,
#
#     LETADOT=F,
#
#     LUPWIND=T,
#
#     LWADV=T,
#
#     LTADV=F,
#
#     LQADV=F,
#
#     LUVADV=F,
#
#     LVARFOR=F,
#
#     LVARSST=F,
#
#     LRELAX=T,
#
#     LUVREL=T,
#
#     LTQREL=F,
#
#     LSFCFLX=F,
#
#     RDTRELAX=900,
#
#     OUTFORM='netcdf',
#
#     CMODID='36r1',
#
#     CSIMID='trref_wind',
#
# /
#
#  &NAMDPHY
#
#     NVXTR2=20,
#
#     NVEXTR=25,
#
#     NCEXTR=91,
#
# /
#
#  &NAMSPSDT
#
#     LSPSDT=F,
#
# /
#
#  &NAMPHYDS
#
# /
#
#  &NAMSIMPHL
#
# /
#
#  &NAMTRAJP
#
# /
#
#  &NAMDDH
#
# /
#
#  &NAPHLC
#
# /
#
#  &NAMPHY
#
# /
#
#  &NAMARPHY
#
# /
#
#  &NAMRCOEF
#
# /
#
#  &NAMSCM
#
# /
#
#  &NAMCUMFS
#
# /
#
#  &NAMTLEVOL
#
# /
#
#  &NAMSTA
#
# /
#
#  &NAMSCEN
#
# /
#
#  &NAMCUMF
#
# /
#
#  &NAMCLDP
#
# /
#
#  &NAMSTOPH
#
# /
#
#  &NAMDYNCORE
#
# /
#
#  &NAMGWD
#
# /
#
#  &NAMGWWMS
#
# /
#
#  &NAMVDF
#
# /
#
#  &NAMMETHOX
#
# /
#
#   &NAMVV1
#
#    DVALH(0)=0.,
#
#      2.000040,
#
#      3.980832,
#
#      7.387186,
#
#     12.908319,
#
#     21.413612,
#
#     33.952858,
#
#     51.746601,
#
#     76.167656,
#
#    108.715561,
#
#    150.986023,
#
#    204.637451,
#
#    271.356506,
#
#    352.824493,
#
#    450.685791,
#
#    566.519226,
#
#    701.813354,
#
#    857.945801,
#
#   1036.166504,
#
#   1237.585449,
#
#   1463.163940,
#
#   1713.709595,
#
#   1989.874390,
#
#   2292.155518,
#
#   2620.898438,
#
#   2976.302246,
#
#   3358.425781,
#
#   3767.196045,
#
#   4202.416504,
#
#   4663.776367,
#
#   5150.859863,
#
#   5663.156250,
#
#   6199.839355,
#
#   6759.727051,
#
#   7341.469727,
#
#   7942.926270,
#
#   8564.624023,
#
#   9208.305664,
#
#   9873.560547,
#
#  10558.881836,
#
#  11262.484375,
#
#  11982.662109,
#
#  12713.897461,
#
#  13453.225586,
#
#  14192.009766,
#
#  14922.685547,
#
#  15638.053711,
#
#  16329.560547,
#
#  16990.623047,
#
#  17613.281250,
#
#  18191.029297,
#
#  18716.968750,
#
#  19184.544922,
#
#  19587.513672,
#
#  19919.796875,
#
#  20175.394531,
#
#  20348.916016,
#
#  20434.158203,
#
#  20426.218750,
#
#  20319.011719,
#
#  20107.031250,
#
#  19785.357422,
#
#  19348.775391,
#
#  18798.822266,
#
#  18141.296875,
#
#  17385.595703,
#
#  16544.585938,
#
#  15633.566406,
#
#  14665.645508,
#
#  13653.219727,
#
#  12608.383789,
#
#  11543.166992,
#
#  10471.310547,
#
#   9405.222656,
#
#   8356.252930,
#
#   7335.164551,
#
#   6353.920898,
#
#   5422.802734,
#
#   4550.215820,
#
#   3743.464355,
#
#   3010.146973,
#
#   2356.202637,
#
#   1784.854614,
#
#   1297.656128,
#
#    895.193542,
#
#    576.314148,
#
#    336.772369,
#
#    162.043427,
#
#     54.208336,
#
#      6.575628,
#
#      0.003160,
#
#      0.000000,
#
#     DVBH(0)= 0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000002724,
#
#  0.0000139116,
#
#  0.0000546672,
#
#  0.0001313641,
#
#  0.0002788848,
#
#  0.0005483841,
#
#  0.0010001344,
#
#  0.0017010754,
#
#  0.0027647193,
#
#  0.0042670486,
#
#  0.0063221669,
#
#  0.0090349903,
#
#  0.0125082629,
#
#  0.0168595780,
#
#  0.0221886449,
#
#  0.0286103487,
#
#  0.0362269096,
#
#  0.0451461338,
#
#  0.0554742292,
#
#  0.0673161894,
#
#  0.0807773024,
#
#  0.0959640592,
#
#  0.1129790097,
#
#  0.1319348216,
#
#  0.1529335231,
#
#  0.1760910898,
#
#  0.2015201300,
#
#  0.2293148786,
#
#  0.2595544755,
#
#  0.2919934094,
#
#  0.3263293803,
#
#  0.3622025847,
#
#  0.3992047608,
#
#  0.4369063377,
#
#  0.4750164151,
#
#  0.5132797360,
#
#  0.5514584780,
#
#  0.5893171430,
#
#  0.6265588999,
#
#  0.6629335880,
#
#  0.6982235909,
#
#  0.7322238088,
#
#  0.7646794915,
#
#  0.7953847647,
#
#  0.8241854310,
#
#  0.8509504199,
#
#  0.8755183816,
#
#  0.8977672458,
#
#  0.9176509380,
#
#  0.9351570606,
#
#  0.9502738118,
#
#  0.9630070925,
#
#  0.9734660387,
#
#  0.9822381139,
#
#  0.9891529679,
#
#  0.9942041636,
#
#  0.9976301193,
#
#  1.0000000000,
#
#  /
#
# &NAEAER
#
# /
#
# &NAEPHY
#
# /
#
# &NAERAD
#
# /
#
# &NALBAR
#
# /
#
# &NALORI
#
# /
#
# &NAM_DISTRIBUTED_VECTORS
#
# /
#
# &NAM926
#
# /
#
# &NAMAFN
#
# /
#
# &NAMANA
#
# /
#
# &NAMARPHY
#
# /
#
# &NAMCA
#
# /
#
# &NAMCAPE
#
# /
#
# &NAMCFU
#
# /
#
# &NAMCHK
#
# /
#
# &NAMCHET
#
# /
#
# &NAMCLDP
#
# /
#
# &NAMCLTC
#
# /
#
# &NAMCOM
#
# /
#
# &NAMCOS
#
# /
#
# &NAMCTAN
#
# /
#
# &NAMCUMF
#
# /
#
# &NAMCUMFS
#
# /
#
# &NAMCT1
#
# /
#
# &NAMCVA
#
# /
#
# &NAMDDH
#
# /
#
# &NAMDFHD
#
# /
#
# &NAMDFI
#
# /
#
# &NAMDIF
#
# /
#
# &NAMDIM
#
# /
#
# &NAMDIMO
#
# /
#
# &NAMDMSP
#
# /
#
# &NAMDPHY
#
# /
#
# &NAMDYN
#
# /
#
# &NAMDYNA
#
# /
#
# &NAMDYNCORE
#
# /
#
# &NAMEMIS_CONF
#
# /
#
# &NAMENKF
#
# /
#
# &NAMFA
#
# /
#
# &NAMFFT
#
# /
#
# &NAMFPC
#
# /
#
# &NAMFPD
#
# /
#
# &NAMFPDY2
#
# /
#
# &NAMFPDYH
#
# /
#
# &NAMFPDYP
#
# /
#
# &NAMFPDYS
#
# /
#
# &NAMFPDYT
#
# /
#
# &NAMFPDYV
#
# /
#
# &NAMFPEZO
#
# /
#
# &NAMFPF
#
# /
#
# &NAMFPG
#
# /
#
# &NAMFPIOS
#
# /
#
# &NAMFPPHY
#
# /
#
# &NAMFPSC2
#
# /
#
# &NAMFPSC2_DEP
#
# /
#
# &NAMFY2
#
# /
#
# &NAMGEM
#
# /
#
# &NAMGFL
#
# /
#
# &NAMGMS
#
# /
#
# &NAMGOES
#
# /
#
# &NAMGOM
#
# /
#
# &NAMGRIB
#
# /
#
# &NAMGWD
#
# /
#
# &NAMGWWMS
#
# /
#
# &NAMHLOPT
#
# /
#
# &NAMINI
#
# /
#
# &NAMIOMI
#
# /
#
# &NAMIOS
#
# /
#
# &NAMJBCODES
#
# /
#
# &NAMJFH
#
# /
#
# &NAMJG
#
# /
#
# &NAMJO
#
# /
#
# &NAMKAP
#
# /
#
# &NAMLCZ
#
# /
#
# &NAMLEG
#
# /
#
# &NAMLFI
#
# /
#
# &NAMMCC
#
# /
#
# &NAMMCUF
#
# /
#
# &NAMMETEOSAT
#
# /
#
# &NAMMTS
#
# /
#
# &NAMMTSAT
#
# /
#
# &NAMMTT
#
# /
#
# &NAMMUL
#
# /
#
# &NAMNMI
#
# /
#
# &NAMNASA
#
# /
#
# &NAMNN
#
# /
#
# &NAMNPROF
#
# /
#
# &NAMNUD
#
# /
#
# &NAMOBS
#
# /
#
# &NAMONEDVAR
#
# /
#
# &NAMOPH
#
# /
#
# &NAMOPTCMEM
#
# /
#
# &NAMPAR0
#
# /
#
# &NAMPARAR
#
# /
#
# &NAMPAR1
#
# /
#
# &NAMPHY
#
# /
#
# &NAMPHY0
#
# /
#
# &NAMPHY1
#
# /
#
# &NAMPHY2
#
# /
#
# &NAMPHY3
#
# /
#
# &NAMPHYDS
#
# /
#
# &NAMPPC
#
# /
#
# &NAMPONG
#
# /
#
# &NAMRAD15
#
# /
#
# &NAMRADCMEM
#
# /
#
# &NAMRCOEF
#
# /
#
# &NAMRES
#
# /
#
# &NAMRINC
#
# /
#
# &NAMRIP
#
# /
#
# &NAMSATS
#
# /
#
# &NAMSCC
#
# /
#
# &NAMSCEN
#
# /
#
# &NAMSCM
#
# /
#
# &NAMSENS
#
# /
#
# &NAMSIMPHL
#
# /
#
# &NAMSKF
#
# /
#
# &NAMSPSDT
#
# /
#
# &NAMSSMI
#
# /
#
# &NAMSTA
#
# /
#
# &NAMSTOPH
#
# /
#
# &NAMTCWV
#
# /
#
# &NAMTESTVAR
#
# /
#
# &NAMTOPH
#
# /
#
# &NAMTOVS
#
# /
#
# &NAMTRAJP
#
# /
#
# &NAMTRANS
#
# /
#
# &NAMTRM
#
# /
#
# &NAMVAR
#
# /
#
# &NAMVARBC
#
# /
#
# &NAMVARBC_AIREP
#
# /
#
# &NAMVARBC_ALLSKY
#
# /
#
# &NAMVARBC_GBRAD
#
# /
#
# &NAMVARBC_RAD
#
# /
#
# &NAMVARBC_SFCOBS
#
# /
#
# &NAMVARBC_TCWV
#
# /
#
# &NAMVARBC_TO3
#
# /
#
# &NAMVAREPS
#
# /
#
# &NAMVDOZ
#
# /
#
# &NAMVFP
#
# /
#
# &NAMVRTL
#
# /
#
# &NAMVV0
#
# /
#
# &NAMVV1
#
# /
#
# &NAMVV2
#
# /
#
# &NAMVWRK
#
# /
#
# &NAMWAVELETJB
#
# /
#
# &NAMXFU
#
# /
#
# &NAMZDI
#
# /
#
# &NAPHLC
#
# /
#
# &NAV1IS
#
# /
#
# &NAEPHLI
#
# /
#
# &NAMCVER
#
# /
#
# &NAMPPVI
#
# /
#
# &NAMSPNG
#
# /

# %%
# Change that variable

get_nl_class = importlib.reload(get_nl_class)
namelist_changer = get_nl_class.NML_Change(namelist_file = "fort.4")
namelist_changer.patch_namelist(tree_field = "NAMARG", subtree_field = "UTSTEP", value = 200.00)
# Out:
# Done changeing!

# %%
# Reload the kernel for good measure

from IPython.display import display_html
display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
# Out:
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
# Call the scm model again
import os
from importlib import reload

if os.path.isdir("test-run"):
    # %cd test-run

os.environ["GFORTRAN_CONVERT_UNIT"] = "big_endian"
import _test1
_test1.f90wrap_cnt1c()
# Out:
# /home/tibi/Desktop/esowc/test-run

# %%
# Plot the Grafic another time

import sys
sys.path.append("..")
from scripts import plot
plot = plot.Plot("diagvar.nc")
plot.plot_parameter(plot_name = "pressure_f")

# %%
# So to recap

# %%
# Copy this cell for running the cnt1c
# Run OpenIfs
import os
from importlib import reload

if os.path.isdir("test-run"):
    # %cd test-run

os.environ["GFORTRAN_CONVERT_UNIT"] = "big_endian"
import _test1
_test1.f90wrap_cnt1c()

# At the end we are also restart the kernel
import os
from IPython.display import display_html
display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)

# %%
# List all the 
import os
from importlib import reload

if os.path.isdir("test-run"):
    # %cd test-run

import scripts.plot as plot

plot = plot.Plot("diagvar.nc")
plot.documentation_nl_names()
# Out:
# <class 'netCDF4._netCDF4.Variable'>
# int32 nlev(nlev)
#     units: count
#     long_name: Atmospheric Model Levels
# unlimited dimensions:
# current shape = (91,)
# filling on, default _FillValue of -2147483647 used
#
# <class 'netCDF4._netCDF4.Variable'>
# int32 nlevp1(nlevp1)
#     units: count
#     long_name: Atmospheric Model Levels
# unlimited dimensions:
# current shape = (92,)
# filling on, default _FillValue of -2147483647 used
#
# <class 'netCDF4._netCDF4.Variable'>
# int32 nlevs(nlevs)
#     units: count
#     long_name: Soil/Sea-Ice Model Levels
# unlimited dimensions:
# current shape = (4,)
# filling on, default _FillValue of -2147483647 used
#
# <class 'netCDF4._netCDF4.Variable'>
# int32 ntiles(ntiles)
#     units: count
#     long_name: Tiles
# unlimited dimensions:
# current shape = (9,)
# filling on, default _FillValue of -2147483647 used
#
# <class 'netCDF4._netCDF4.Variable'>
# int32 norg(norg)
#     units: count
#     long_name: Orographic Variances
# unlimited dimensions:
# current shape = (4,)
# filling on, default _FillValue of -2147483647 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 time(time)
#     units: seconds
#     long_name: Time
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# int32 ncextr(ncextr)
#     units: count
#     long_name: Extra Variable Levels
# unlimited dimensions:
# current shape = (91,)
# filling on, default _FillValue of -2147483647 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 pressure_f(time, nlev)
#     units: Pa
#     long_name: Pressure - full levels
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 pressure_h(time, nlevp1)
#     units: Pa
#     long_name: Pressure - half levels
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 height_f(time, nlev)
#     units: m
#     long_name: Height - full levels
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 height_h(time, nlevp1)
#     units: m
#     long_name: Height - half levels
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 wat_vap_path(time)
#     units: kg/m^2
#     long_name: Water Vapor Path
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 liq_wat_path(time)
#     units: kg/m^2
#     long_name: Liquid Water Path
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 ice_wat_path(time)
#     units: kg/m^2
#     long_name: Ice Water Path
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 pbl_height(time)
#     units: m
#     long_name: Boundary Layer Height
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 total_cloud(time)
#     units: 1
#     long_name: Total Cloud Cover
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 low_cloud(time)
#     units: 1
#     long_name: Low Cloud Cover
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 middle_cloud(time)
#     units: 1
#     long_name: Middle Cloud Cover
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 high_cloud(time)
#     units: 1
#     long_name: High Cloud Cover
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 conv_rain(time)
#     units: kg/m^2/s
#     long_name: Convective Rain
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 conv_snow(time)
#     units: kg/m^2/s
#     long_name: Convective Snow
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 stra_rain(time)
#     units: kg/m^2/s
#     long_name: Stratiform Rain
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 stra_snow(time)
#     units: kg/m^2/s
#     long_name: Stratiform Snow
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 top_swrad_inc(time)
#     units: W/m^2
#     long_name: Top SW Radiation Incoming
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 conv_type(time)
#     units: 0/1/2/3
#     long_name: Deep/Shallow/Midlevel Convection
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 pbl_type(time)
#     units: 0/1/2/3
#     long_name: Dry stable/Dry conv/Sc/Cu
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 n_conv_base(time)
#     units: 1
#     long_name: Index of Convective Cloud Base
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 n_conv_top(time)
#     units: 1
#     long_name: Index of Convective Cloud Top
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 top_swrad(time)
#     units: W/m^2
#     long_name: Top SW Radiation
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 top_swrad_clr(time)
#     units: W/m^2
#     long_name: Top SW Radiation Clear-Sky
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 top_lwrad(time)
#     units: W/m^2
#     long_name: Top LW Radiation
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 top_lwrad_clr(time)
#     units: W/m^2
#     long_name: Top LW Radiation Clear-Sky
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sfc_swrad(time)
#     units: W/m^2
#     long_name: Surface SW Radiation
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sfc_swrad_clr(time)
#     units: W/m^2
#     long_name: Surface SW Radiation Clear-Sky
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sfc_lwrad(time)
#     units: W/m^2
#     long_name: Surface LW Radiation
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sfc_lwrad_clr(time)
#     units: W/m^2
#     long_name: Surface LW Radiation Clear-Sky
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sfc_swrad_down(time)
#     units: W/m^2
#     long_name: Surface Downward SW Radiation
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sfc_albedo(time)
#     units: 1
#     long_name: Surface SW Albedo
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sfc_lwrad_down(time)
#     units: W/m^2
#     long_name: Surface Downward LW Radiation
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sfc_emiss(time)
#     units: 1
#     long_name: Surface Emissivity
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sfc_sen_flx(time)
#     units: W/m^2
#     long_name: Surface Sensible Heat Flux
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sfc_lat_flx(time)
#     units: W/m^2
#     long_name: Surface Latent Heat Flux
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 u_sfc_strss(time)
#     units:
#     long_name: U-Surface Stress
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 v_sfc_strss(time)
#     units:
#     long_name: V-Surface Stress
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sfc_sen_flx_ti(time, nlev)
#     units: W/m^2
#     long_name: Tiled Surface Sensible Heat Flux
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sfc_lat_flx_ti(time, nlev)
#     units: W/m^2
#     long_name: Tiled Surface Latent Heat Flux
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 u_sfc_strss_ti(time, nlev)
#     units: N/m^2
#     long_name: Tiled U Surface Stress
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 v_sfc_strss_ti(time, nlev)
#     units: N/m^2
#     long_name: Tiled V Surface Stress
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sst(time)
#     units: K
#     long_name: Sea Surface Temperature
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 t_skin_ti(time, nlev)
#     units: K
#     long_name: Tiled Skin Temperature
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 land_sea_mask(time)
#     units: 0-1
#     long_name: Land-Sea Mask
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sea_ice_cov(time)
#     units: 0-1
#     long_name: Sea Ice Fraction
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 rough_len_mom(time)
#     units: m
#     long_name: Surface Roughness length
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 rough_len_heat(time)
#     units: m
#     long_name: Surface Roughness Length for Heat
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 low_veg_cov(time)
#     units: 0-1
#     long_name: Low Vegetation Cover
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 high_veg_cov(time)
#     units: 0-1
#     long_name: High Vegetation Cover
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 low_veg_type(time)
#     units: 1-20
#     long_name: Low Vegetation Type
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 high_veg_type(time)
#     units: 1-20
#     long_name: High Vegetation Type
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 turb_diss(time)
#     units:
#     long_name: Turbulent Dissipation
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 gwd_diss(time)
#     units:
#     long_name: Gravity Wave Drag Dissipation
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 gwd_u_strs(time)
#     units:
#     long_name: Gravity Wave Drag Surface U-Stress
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 gwd_v_strs(time)
#     units:
#     long_name: Gravity Wave Drag Surface V-Stress
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 u_wind_10m(time)
#     units: m/s
#     long_name: U-Wind 10m
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 v_wind_10m(time)
#     units: m/s
#     long_name: V-Wind 10m
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 temperature_2m(time)
#     units: K
#     long_name: Temperature 2m
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 dew_point_2m(time)
#     units: K
#     long_name: Dew Point Temperature 2m
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 wind_gust(time)
#     units: m/s
#     long_name: Wind Gust at 10m
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sun_duration(time)
#     units: 0-1
#     long_name: Sunshine Duration
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 runoff(time)
#     units:
#     long_name: Run-off
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sfc_sen_flx_ext(time)
#     units: W/m^2
#     long_name: External Sensible Heat Flux
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sfc_lat_flx_ext(time)
#     units: W/m^2
#     long_name: External Latent Heat Flux
# unlimited dimensions: time
# current shape = (289,)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 dir_orog_var(time, norg)
#     units:
#     long_name: Directional Orographic Variances
# unlimited dimensions: time
# current shape = (289, 4)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 ls_prec_fct(time, nlev)
#     units: 0-1
#     long_name: Large-scale Precipitation Fraction
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_u_wind(time, nlev)
#     units: m/s^2
#     long_name: Tendency of U-Wind
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_u_wind_d(time, nlev)
#     units: m/s^2
#     long_name: Tendency of U-Wind (dyn)
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_u_wind_p(time, nlev)
#     units: m/s^2
#     long_name: Tendency of U-Wind (phy)
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_v_wind(time, nlev)
#     units: m/s^2
#     long_name: Tendency of V-Wind
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_v_wind_d(time, nlev)
#     units: m/s^2
#     long_name: Tendency of V-Wind (dyn)
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_v_wind_p(time, nlev)
#     units: m/s^2
#     long_name: Tendency of V-Wind (phy)
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_temp(time, nlev)
#     units: K/s
#     long_name: Tendency of Temperature
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_temp_d(time, nlev)
#     units: K/s
#     long_name: Tendency of Temperature (dyn)
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_temp_p(time, nlev)
#     units: K/s
#     long_name: Tendency of Temperature (phy)
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_wat_vap(time, nlev)
#     units: 1/s
#     long_name: Tendency of Water Vapor
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_wat_vap_d(time, nlev)
#     units: 1/s
#     long_name: Tendency of Water Vapor (dyn)
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_wat_vap_p(time, nlev)
#     units: 1/s
#     long_name: Tendency of Water Vapor (phy)
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_cld_fract(time, nlev)
#     units: 1/s
#     long_name: Tendency of Cloud Fraction
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_cld_fract_d(time, nlev)
#     units: 1/s
#     long_name: Tendency of Cloud Fraction (dyn)
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_cld_fract_p(time, nlev)
#     units: 1/s
#     long_name: Tendency of Cloud Fraction (phy)
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_cld_liq(time, nlev)
#     units: 1/s
#     long_name: Tendency of Cloud Liq. Water
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_cld_liq_d(time, nlev)
#     units: 1/s
#     long_name: Tendency of Cloud Liq. Water (dyn)
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_cld_liq_p(time, nlev)
#     units: 1/s
#     long_name: Tendency of Cloud Liq. Water (phy)
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_cld_ice(time, nlev)
#     units: 1/s
#     long_name: Tendency of Cloud Ice Water
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_cld_ice_d(time, nlev)
#     units: 1/s
#     long_name: Tendency of Cloud Ice Water (dyn)
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 tend_cld_ice_p(time, nlev)
#     units: 1/s
#     long_name: Tendency of Cloud Ice Water (phy)
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 stra_rain_3d(time, nlevp1)
#     units:
#     long_name: Stratiform Rain 3D
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 stra_snow_3d(time, nlevp1)
#     units:
#     long_name: Stratiform Snow 3D
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 conv_rain_3d(time, nlevp1)
#     units:
#     long_name: Convective Rain 3D
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 conv_snow_3d(time, nlevp1)
#     units:
#     long_name: Convective Snow 3D
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 conv_flx_wv(time, nlevp1)
#     units:
#     long_name: Conv. Flux of WV
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 conv_flx_s(time, nlevp1)
#     units: W/m^2
#     long_name: Conv. Flux of Dry Static Energy
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 conv_flx_u(time, nlevp1)
#     units:
#     long_name: Convective U-Momentum Flux
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 conv_flx_v(time, nlevp1)
#     units:
#     long_name: Convective V-Momentum Flux
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 cond_detrained_updr(time, nlev)
#     units:
#     long_name: Detrained liquid water
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 cond_updraft(time, nlev)
#     units:
#     long_name: Liquid water content in updrafts
# unlimited dimensions: time
# current shape = (289, 91)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 turb_flx_wv(time, nlevp1)
#     units:
#     long_name: Turb. Flux (inc. neg q) of WV
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 turb_flx_s(time, nlevp1)
#     units: W/m^2
#     long_name: Turb. Flux of Dry Static Energy
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 turb_flx_u(time, nlevp1)
#     units:
#     long_name: Turbulent Flux of U-Momentum
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 turb_flx_v(time, nlevp1)
#     units:
#     long_name: Turbulent Flux of V-Momentum
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 turb_flx_ice(time, nlevp1)
#     units:
#     long_name: Turbulent Flux (inc. neg. q) of Ice Water
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 turb_flx_liq(time, nlevp1)
#     units:
#     long_name: Turbulent Flux (inc. neg. q) of Liq. Water
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 gwd_flx_u(time, nlevp1)
#     units:
#     long_name: Gravity Wave Drag U-Flux
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 gwd_flx_v(time, nlevp1)
#     units:
#     long_name: Gravity Wave Drag V-Flux
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 sw_rad_flux(time, nlevp1)
#     units:
#     long_name: SW radiative Flux
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used
#
# <class 'netCDF4._netCDF4.Variable'>
# float32 lw_rad_flux(time, nlevp1)
#     units:
#     long_name: LW radiative Flux
# unlimited dimensions: time
# current shape = (289, 92)
# filling on, default _FillValue of 9.969209968386869e+36 used

# %%
# Call the plot function and plot the result.
# Change the selected plot variable

selected_plot_var = "pressure_f"
plot.plot_parameter(plot_name = selected_plot_var)

# %%
# Change the fortran Namelist
# Firstly look for what variable you want to change
# We are changeing the namelist directly in the fort.4 file
from importlib import reload
from scripts import get_nl_class

get_nl_class = reload(get_nl_class)
namelist_changer = get_nl_class.NML_Change(namelist_file = "fort.4")
namelist_changer.read_nml()
namelist_changer.print_namelists_from_file()
# Out:
#  &NAMCT0
#
#     NFRPOS=1,
#
#     LSLPHY=.false. ! F for euler
#
#     LTWOTL=T,
#
#     LREGETA=T, ! F for euler
#
#     NUNDEFLD=1, ! for bound checking
#
# /
#
#  &NAMARG
#
#   UTSTEP=200.0 ! 300.0, for euler
#
#   LSLAG=T, ! F for euler
#
# /
#
#  &NAMRIP
#
#   NSTOP=288, ! 864, for euler
#
# /
#
#  &NAMCVER
#
#   LVERTFE=.false.,
#
# /
#
#  &NAMDYN
#
#     NITMP=3, ! makes advection further more accurate
#
#     ! LSETTLS=.false., ! alternative SL scheme
#
# /
#
#  &NAERAD
#
#     NRADFR=1,
#
#     LSRTM=T,
#
#     NLIQOPT=2,
#
#     NRADINT=0,
#
#     NRPROMA=-1,
#
# /
#
#  &NAMDIM
#
#     NFLEVG=91,
#
# 	NIOLEVG=91,
#
#     NSMAX=159,
#
#     NSTENCILWIDE=1,
#
#     NPROMA=-1,
#
#     NDGLG=1,
#
#     NDLON=1,
#
# /
#
#  &NAEPHY
#
#     LEPHYS=T,
#
#     LEFLAKE=T,
#
#     LESURF=T,
#
#     LEVDIF=T,
#
#     LECUMF=T,
#
#     LEPCLD=T,
#
#     LEQNGT=T,
#
#     LEGWDG=T,
#
#     LERADI=T,
#
#     LEGWWMS=T,
#
#     LBUD23=F,
#
# /
#
#  &NAM1C
#
#     NSTRTINI=3
#
#     LDYNFOR=T,
#
#     LUGVG=F,
#
#     LVERVEL=T,
#
#     LETADOT=F,
#
#     LUPWIND=T,
#
#     LWADV=T,
#
#     LTADV=F,
#
#     LQADV=F,
#
#     LUVADV=F,
#
#     LVARFOR=F,
#
#     LVARSST=F,
#
#     LRELAX=T,
#
#     LUVREL=T,
#
#     LTQREL=F,
#
#     LSFCFLX=F,
#
#     RDTRELAX=900,
#
#     OUTFORM='netcdf',
#
#     CMODID='36r1',
#
#     CSIMID='trref_wind',
#
# /
#
#  &NAMDPHY
#
#     NVXTR2=20,
#
#     NVEXTR=25,
#
#     NCEXTR=91,
#
# /
#
#  &NAMSPSDT
#
#     LSPSDT=F,
#
# /
#
#  &NAMPHYDS
#
# /
#
#  &NAMSIMPHL
#
# /
#
#  &NAMTRAJP
#
# /
#
#  &NAMDDH
#
# /
#
#  &NAPHLC
#
# /
#
#  &NAMPHY
#
# /
#
#  &NAMARPHY
#
# /
#
#  &NAMRCOEF
#
# /
#
#  &NAMSCM
#
# /
#
#  &NAMCUMFS
#
# /
#
#  &NAMTLEVOL
#
# /
#
#  &NAMSTA
#
# /
#
#  &NAMSCEN
#
# /
#
#  &NAMCUMF
#
# /
#
#  &NAMCLDP
#
# /
#
#  &NAMSTOPH
#
# /
#
#  &NAMDYNCORE
#
# /
#
#  &NAMGWD
#
# /
#
#  &NAMGWWMS
#
# /
#
#  &NAMVDF
#
# /
#
#  &NAMMETHOX
#
# /
#
#   &NAMVV1
#
#    DVALH(0)=0.,
#
#      2.000040,
#
#      3.980832,
#
#      7.387186,
#
#     12.908319,
#
#     21.413612,
#
#     33.952858,
#
#     51.746601,
#
#     76.167656,
#
#    108.715561,
#
#    150.986023,
#
#    204.637451,
#
#    271.356506,
#
#    352.824493,
#
#    450.685791,
#
#    566.519226,
#
#    701.813354,
#
#    857.945801,
#
#   1036.166504,
#
#   1237.585449,
#
#   1463.163940,
#
#   1713.709595,
#
#   1989.874390,
#
#   2292.155518,
#
#   2620.898438,
#
#   2976.302246,
#
#   3358.425781,
#
#   3767.196045,
#
#   4202.416504,
#
#   4663.776367,
#
#   5150.859863,
#
#   5663.156250,
#
#   6199.839355,
#
#   6759.727051,
#
#   7341.469727,
#
#   7942.926270,
#
#   8564.624023,
#
#   9208.305664,
#
#   9873.560547,
#
#  10558.881836,
#
#  11262.484375,
#
#  11982.662109,
#
#  12713.897461,
#
#  13453.225586,
#
#  14192.009766,
#
#  14922.685547,
#
#  15638.053711,
#
#  16329.560547,
#
#  16990.623047,
#
#  17613.281250,
#
#  18191.029297,
#
#  18716.968750,
#
#  19184.544922,
#
#  19587.513672,
#
#  19919.796875,
#
#  20175.394531,
#
#  20348.916016,
#
#  20434.158203,
#
#  20426.218750,
#
#  20319.011719,
#
#  20107.031250,
#
#  19785.357422,
#
#  19348.775391,
#
#  18798.822266,
#
#  18141.296875,
#
#  17385.595703,
#
#  16544.585938,
#
#  15633.566406,
#
#  14665.645508,
#
#  13653.219727,
#
#  12608.383789,
#
#  11543.166992,
#
#  10471.310547,
#
#   9405.222656,
#
#   8356.252930,
#
#   7335.164551,
#
#   6353.920898,
#
#   5422.802734,
#
#   4550.215820,
#
#   3743.464355,
#
#   3010.146973,
#
#   2356.202637,
#
#   1784.854614,
#
#   1297.656128,
#
#    895.193542,
#
#    576.314148,
#
#    336.772369,
#
#    162.043427,
#
#     54.208336,
#
#      6.575628,
#
#      0.003160,
#
#      0.000000,
#
#     DVBH(0)= 0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000000000,
#
#  0.0000002724,
#
#  0.0000139116,
#
#  0.0000546672,
#
#  0.0001313641,
#
#  0.0002788848,
#
#  0.0005483841,
#
#  0.0010001344,
#
#  0.0017010754,
#
#  0.0027647193,
#
#  0.0042670486,
#
#  0.0063221669,
#
#  0.0090349903,
#
#  0.0125082629,
#
#  0.0168595780,
#
#  0.0221886449,
#
#  0.0286103487,
#
#  0.0362269096,
#
#  0.0451461338,
#
#  0.0554742292,
#
#  0.0673161894,
#
#  0.0807773024,
#
#  0.0959640592,
#
#  0.1129790097,
#
#  0.1319348216,
#
#  0.1529335231,
#
#  0.1760910898,
#
#  0.2015201300,
#
#  0.2293148786,
#
#  0.2595544755,
#
#  0.2919934094,
#
#  0.3263293803,
#
#  0.3622025847,
#
#  0.3992047608,
#
#  0.4369063377,
#
#  0.4750164151,
#
#  0.5132797360,
#
#  0.5514584780,
#
#  0.5893171430,
#
#  0.6265588999,
#
#  0.6629335880,
#
#  0.6982235909,
#
#  0.7322238088,
#
#  0.7646794915,
#
#  0.7953847647,
#
#  0.8241854310,
#
#  0.8509504199,
#
#  0.8755183816,
#
#  0.8977672458,
#
#  0.9176509380,
#
#  0.9351570606,
#
#  0.9502738118,
#
#  0.9630070925,
#
#  0.9734660387,
#
#  0.9822381139,
#
#  0.9891529679,
#
#  0.9942041636,
#
#  0.9976301193,
#
#  1.0000000000,
#
#  /
#
# &NAEAER
#
# /
#
# &NAEPHY
#
# /
#
# &NAERAD
#
# /
#
# &NALBAR
#
# /
#
# &NALORI
#
# /
#
# &NAM_DISTRIBUTED_VECTORS
#
# /
#
# &NAM926
#
# /
#
# &NAMAFN
#
# /
#
# &NAMANA
#
# /
#
# &NAMARPHY
#
# /
#
# &NAMCA
#
# /
#
# &NAMCAPE
#
# /
#
# &NAMCFU
#
# /
#
# &NAMCHK
#
# /
#
# &NAMCHET
#
# /
#
# &NAMCLDP
#
# /
#
# &NAMCLTC
#
# /
#
# &NAMCOM
#
# /
#
# &NAMCOS
#
# /
#
# &NAMCTAN
#
# /
#
# &NAMCUMF
#
# /
#
# &NAMCUMFS
#
# /
#
# &NAMCT1
#
# /
#
# &NAMCVA
#
# /
#
# &NAMDDH
#
# /
#
# &NAMDFHD
#
# /
#
# &NAMDFI
#
# /
#
# &NAMDIF
#
# /
#
# &NAMDIM
#
# /
#
# &NAMDIMO
#
# /
#
# &NAMDMSP
#
# /
#
# &NAMDPHY
#
# /
#
# &NAMDYN
#
# /
#
# &NAMDYNA
#
# /
#
# &NAMDYNCORE
#
# /
#
# &NAMEMIS_CONF
#
# /
#
# &NAMENKF
#
# /
#
# &NAMFA
#
# /
#
# &NAMFFT
#
# /
#
# &NAMFPC
#
# /
#
# &NAMFPD
#
# /
#
# &NAMFPDY2
#
# /
#
# &NAMFPDYH
#
# /
#
# &NAMFPDYP
#
# /
#
# &NAMFPDYS
#
# /
#
# &NAMFPDYT
#
# /
#
# &NAMFPDYV
#
# /
#
# &NAMFPEZO
#
# /
#
# &NAMFPF
#
# /
#
# &NAMFPG
#
# /
#
# &NAMFPIOS
#
# /
#
# &NAMFPPHY
#
# /
#
# &NAMFPSC2
#
# /
#
# &NAMFPSC2_DEP
#
# /
#
# &NAMFY2
#
# /
#
# &NAMGEM
#
# /
#
# &NAMGFL
#
# /
#
# &NAMGMS
#
# /
#
# &NAMGOES
#
# /
#
# &NAMGOM
#
# /
#
# &NAMGRIB
#
# /
#
# &NAMGWD
#
# /
#
# &NAMGWWMS
#
# /
#
# &NAMHLOPT
#
# /
#
# &NAMINI
#
# /
#
# &NAMIOMI
#
# /
#
# &NAMIOS
#
# /
#
# &NAMJBCODES
#
# /
#
# &NAMJFH
#
# /
#
# &NAMJG
#
# /
#
# &NAMJO
#
# /
#
# &NAMKAP
#
# /
#
# &NAMLCZ
#
# /
#
# &NAMLEG
#
# /
#
# &NAMLFI
#
# /
#
# &NAMMCC
#
# /
#
# &NAMMCUF
#
# /
#
# &NAMMETEOSAT
#
# /
#
# &NAMMTS
#
# /
#
# &NAMMTSAT
#
# /
#
# &NAMMTT
#
# /
#
# &NAMMUL
#
# /
#
# &NAMNMI
#
# /
#
# &NAMNASA
#
# /
#
# &NAMNN
#
# /
#
# &NAMNPROF
#
# /
#
# &NAMNUD
#
# /
#
# &NAMOBS
#
# /
#
# &NAMONEDVAR
#
# /
#
# &NAMOPH
#
# /
#
# &NAMOPTCMEM
#
# /
#
# &NAMPAR0
#
# /
#
# &NAMPARAR
#
# /
#
# &NAMPAR1
#
# /
#
# &NAMPHY
#
# /
#
# &NAMPHY0
#
# /
#
# &NAMPHY1
#
# /
#
# &NAMPHY2
#
# /
#
# &NAMPHY3
#
# /
#
# &NAMPHYDS
#
# /
#
# &NAMPPC
#
# /
#
# &NAMPONG
#
# /
#
# &NAMRAD15
#
# /
#
# &NAMRADCMEM
#
# /
#
# &NAMRCOEF
#
# /
#
# &NAMRES
#
# /
#
# &NAMRINC
#
# /
#
# &NAMRIP
#
# /
#
# &NAMSATS
#
# /
#
# &NAMSCC
#
# /
#
# &NAMSCEN
#
# /
#
# &NAMSCM
#
# /
#
# &NAMSENS
#
# /
#
# &NAMSIMPHL
#
# /
#
# &NAMSKF
#
# /
#
# &NAMSPSDT
#
# /
#
# &NAMSSMI
#
# /
#
# &NAMSTA
#
# /
#
# &NAMSTOPH
#
# /
#
# &NAMTCWV
#
# /
#
# &NAMTESTVAR
#
# /
#
# &NAMTOPH
#
# /
#
# &NAMTOVS
#
# /
#
# &NAMTRAJP
#
# /
#
# &NAMTRANS
#
# /
#
# &NAMTRM
#
# /
#
# &NAMVAR
#
# /
#
# &NAMVARBC
#
# /
#
# &NAMVARBC_AIREP
#
# /
#
# &NAMVARBC_ALLSKY
#
# /
#
# &NAMVARBC_GBRAD
#
# /
#
# &NAMVARBC_RAD
#
# /
#
# &NAMVARBC_SFCOBS
#
# /
#
# &NAMVARBC_TCWV
#
# /
#
# &NAMVARBC_TO3
#
# /
#
# &NAMVAREPS
#
# /
#
# &NAMVDOZ
#
# /
#
# &NAMVFP
#
# /
#
# &NAMVRTL
#
# /
#
# &NAMVV0
#
# /
#
# &NAMVV1
#
# /
#
# &NAMVV2
#
# /
#
# &NAMVWRK
#
# /
#
# &NAMWAVELETJB
#
# /
#
# &NAMXFU
#
# /
#
# &NAMZDI
#
# /
#
# &NAPHLC
#
# /
#
# &NAV1IS
#
# /
#
# &NAEPHLI
#
# /
#
# &NAMCVER
#
# /
#
# &NAMPPVI
#
# /
#
# &NAMSPNG
#
# /

# %%
# After choosing the varibales that you want to change
# Copy this cell and change the 3 variables at the top
import importlib
namelist = "NAMARG"
variable = "UTSTEP"
value = 200.00
get_nl_class = importlib.reload(get_nl_class)
namelist_changer = get_nl_class.NML_Change(namelist_file = "fort.4")
namelist_changer.patch_namelist(tree_field = namelist, subtree_field = variable, value = value )
# Out:
# Done changeing!

# %%
# Copy the running cell and press enter
# Copy this cell for running the cnt1c
# Run OpenIfs
import os
from importlib import reload

if os.path.isdir("test-run"):
    # %cd test-run

os.environ["GFORTRAN_CONVERT_UNIT"] = "big_endian"
import _test1
_test1.f90wrap_cnt1c()

# At the end we are also restart the kernel
import os
from IPython.display import display_html
display_html("<script>Jupyter.notebook.kernel.restart()</script>",raw=True)
# Out:
# /home/tibi/Desktop/esowc/test-run
# <script>Jupyter.notebook.kernel.restart()</script>

# %%
# Now Copy the 2 plotting cells and rerun them
import os
from importlib import reload

if os.path.isdir("test-run"):
    # %cd test-run

import scripts.plot as plot

plot = plot.Plot("diagvar.nc")
plot.documentation_nl_names()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-906dab42ff0a> in <module>
#       3
#       4 plot = plot.Plot("diagvar.nc")
# ----> 5 plot.documentation_nl_names()
#
# ~/Desktop/esowc/scripts/plot.py in documentation_nl_names(self, write_file)
#      17         def documentation_nl_names(self, write_file = "default.txt"):
#      18
# ---> 19                 fh = Dataset(self.nc_file, mode='r')
#      20
#      21                 with open(write_file, "w") as wf:
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4.Dataset.__init__()
#
# netCDF4/_netCDF4.pyx in netCDF4._netCDF4._ensure_nc_success()
#
# FileNotFoundError: [Errno 2] No such file or directory: b'diagvar.nc'

# %%
# Call the plot function and plot the result.
# Change the selected plot variable

selected_plot_var = "pressure_f"
plot.plot_parameter(plot_name = selected_plot_var)
